# %% [markdown]
# <a href="https://colab.research.google.com/github/luisfernandorutti43-wq/PANDA/blob/main/Copia_de_PANDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#IMPORTAR DE LA LIBRERIA PANDA
import pandas as pd

# %%
#ayuda de pandas
help(pd.Series.iloc)
# Out:
# Help on property:
#
#     Purely integer-location based indexing for selection by position.
#
#     .. deprecated:: 2.2.0
#
#        Returning a tuple from a callable is deprecated.
#
#     ``.iloc[]`` is primarily integer position based (from ``0`` to
#     ``length-1`` of the axis), but may also be used with a boolean
#     array.
#
#     Allowed inputs are:
#
#     - An integer, e.g. ``5``.
#     - A list or array of integers, e.g. ``[4, 3, 0]``.
#     - A slice object with ints, e.g. ``1:7``.
#     - A boolean array.
#     - A ``callable`` function with one argument (the calling Series or
#       DataFrame) and that returns valid output for indexing (one of the above).
#       This is useful in method chains, when you don't have a reference to the
#       calling object, but would like to base your selection on
#       some value.
#     - A tuple of row and column indexes. The tuple elements consist of one of the
#       above inputs, e.g. ``(0, 1)``.
#
# ...

# %% [markdown]
# toma de contactos

# %%
dicionario = [{'a':1,'b':5,'c':9 },{'a':3,'b':5,'c':7} ]
DF= pd.DataFrame(dicionario)
DF
# Out:
#    a  b  c
# 0  1  5  9
# 1  3  5  7
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# DF['a'].plot(kind='hist', bins=20, title='a')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# DF['c'].plot(kind='hist', bins=20, title='c')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# DF.plot(kind='scatter', x='a', y='c', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
DF.plot(kind='scatter', x='a', y='c', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
DF['c'].plot(kind='line', figsize=(8, 4), title='c')
plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# serie

# %%
serie = pd.series({2,3,4,5,6,7,8,9}, index={'a','b','c','d','e'})
serie
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-35-2800990563.py in <cell line: 0>()
# ----> 1 serie = pd.series({2,3,4,5,6,7,8,9}, index={'a','b','c','d','e'})
#       2 serie
#
# AttributeError: module 'pandas' has no attribute 'series'

# %%
#borrar serie o filas
serie=Series.drop(['a','b'])
serie
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-32-3745802616.py in <cell line: 0>()
#       1 #borrar serie o filas
# ----> 2 serie=Series.drop(['a','b'])
#       3 serie
#
# NameError: name 'Series' is not defined

# %%
#selecionar filas o series
serie1=serie(['a','b'])
serie1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-33-3878725158.py in <cell line: 0>()
#       1 #selecionar filas o series
# ----> 2 serie1=serie(['a','b'])
#       3 serie1
#
# TypeError: 'Series' object is not callable

# %%
#Asignacion
serie['b']=100
serie
# Out:
# a      2
# b    100
# c      4
# d      5
# e      6
# dtype: int64

# %%
#operadore
serie4=(serie+serie1)
serie4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-24-496237468.py in <cell line: 0>()
#       1 #operadore
# ----> 2 serie4=(serie+serie1)
#       3 serie4
#
# NameError: name 'serie1' is not defined

# %% [markdown]
# DATEFRAME

# %%
datos = {'alumno':['M Marcos','L Luisa','E Eva'],'Nota':[20,10,15,] }
df=pd.DataFrame(datos,columns=['alumno','Nota'])
df
# Out:
#      alumno  Nota
# 0  M Marcos    20
# 1   L Luisa    10
# 2     E Eva    15

# %%
#cambiar la nota de Marcos y de Eva
datos = {'alumno':['M Marcos','L Luisa','E Eva'],'Nota':[10,10,20,] }
df=pd.DataFrame(datos,columns=['alumno','Nota'])
df
# Out:
#      alumno  Nota
# 0  M Marcos    10
# 1   L Luisa    10
# 2     E Eva    20

# %%
df={'alumno':['M Marcos'],'Notas':[10]}

# %%
#entrada  salida lectura y escritura
csvaa= df.to_csv('/content/misDatos.csv',index=False,columns={'Alumno','Nota'})
print(csvaa)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-60-2944710667.py in <cell line: 0>()
#       1 #entrada  salida lectura y escritura
# ----> 2 csvaa= df.to_csv('/content/misDatos.csv',index=False,columns={'Alumno','Nota'})
#       3 print(csvaa)
#
# AttributeError: 'dict' object has no attribute 'to_csv'

# %%
mid_datos =pd.read_csv('/content/misDatos.csv'header=None,mrows=2)
mid_datos.columns=['Alumno','Nota']
mid_datos.head()
# Out:
#   File "/tmp/ipython-input-63-119440221.py", line 1
#     mid_datos =pd.read_csv('/content/misDatos.csv'header=None,mrows=2)
#                            ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df=pd.read_csv('/content/misDatos.xisv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-64-168945040.py in <cell line: 0>()
# ----> 1 df=pd.read_csv('/content/misDatos.xisv')
#       2 df
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...
